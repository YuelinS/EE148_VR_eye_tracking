# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('image', cmap='gray')
from EyeTracking import EyeTrackingDataset

# %%
dir_images = r'E:\Data\Unity\Minos\imagesBlink'
path_pos = r'E:\Data\Unity\Minos\posBlink.bin'
dataset = EyeTrackingDataset(path_pos, dir_images, polar=True)

# %%
plt.imshow(np.asarray(dataset[0][0]))
plt.show()

# %%
print(dataset[0][1])
print(dataset[0][2])
print(dataset[0][3])
# Out:
# [0. 0. 1.]
# [-1.7681841e-02  5.7216364e-01  2.4264458e+03]
# True

# %%
print([x.shape for x in dataset[0][1:]])
# Out:
# [(3,), (3,), ()]

# %%
print(len(dataset))
# Out:
# 6400

# %%
dataset.dt_pos
# Out:
# dtype([('timestamp', '<i8'), ('x', '<f4'), ('y', '<f4'), ('z', '<f4'), ('x_fove', '<f4'), ('y_fove', '<f4'), ('z_fove', '<f4'), ('is_open', '?')])

# %%
dataset.is_open.sum()
# Out:
# 2814
