# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('image', cmap='gray')
from EyeTrackingV3 import EyeTrackingDataset
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, utils
import os

# %%
dir_images = r'D:\Data\Unity\Minos\imagesFix3'
path_pos = r'D:\Data\Unity\Minos\posFix3.bin'

# %%
dataset = EyeTrackingDataset(path_pos, dir_images, transform=None, polar=True, eye='both', coord_3d=True, combine_open=False, use_fove_gaze=False)

plt.imshow(np.asarray(dataset[0][0]))
plt.show()
print(dataset[0][1])
if len(dataset[0])>2:
    print(dataset[0][2])
# Out:
# [-26.        19.875244   0.4     ]
# True
