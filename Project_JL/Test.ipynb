# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('image', cmap='gray')
from EyeTracking import EyeTrackingDataset

# %%
dir_images = r'E:\Data\Unity\Minos\Fixation Training Images'
path_pos = r'E:\Data\Unity\Minos\Fixation Training Pos.bin'
dataset = EyeTrackingDataset(path_pos, dir_images)

# %%
plt.imshow(np.asarray(dataset[0][0]))
plt.show()

# %%
print(dataset[0][1])
# Out:
# [-5.76756954  3.30764818  9.98972416]

# %%
print(np.asarray(dataset[0][0]).shape, dataset[0][1].shape)
# Out:
# (240, 640, 3) (3,)

# %%
print(len(dataset))
# Out:
# 64000
