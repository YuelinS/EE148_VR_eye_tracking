# %%
import h5py
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
from collections import OrderedDict
from DeepVOG_torch import DeepVOG

# %%
def tf_conv2d_to_torch(h5_group, prefix=''):
    return OrderedDict({
        prefix+'weight': torch.Tensor(h5_group['kernel:0'][()].transpose((3, 2, 0, 1))),
        prefix+'bias': torch.Tensor(h5_group['bias:0'][()]),
    })

def tf_bn_to_torch(h5_group, prefix=''):
    return OrderedDict({
        prefix+'weight' : torch.Tensor(h5_group['gamma:0'][()]),
        prefix+'bias' : torch.Tensor(h5_group['beta:0'][()]),
        prefix+'running_mean' : torch.Tensor(h5_group['moving_mean:0'][()]),
        prefix+'running_var' : torch.Tensor(h5_group['moving_variance:0'][()]),
        prefix+'num_batches_tracked' : torch.Tensor(np.zeros(())).type(torch.int64),
    })

# %%
f = h5py.File('DeepVOG/deepvog/model/DeepVOG_weights.h5', 'r')

# %%
def print_name_shape(name, obj):
    if isinstance(obj, h5py._hl.dataset.Dataset):
        print(f'{name:60} {str(tuple(obj.shape)):15}')

# %%
f.visititems(print_name_shape)
# Out:
# bn_down1_down/bn_down1_down/beta:0                           (32,)
# bn_down1_down/bn_down1_down/gamma:0                          (32,)
# bn_down1_down/bn_down1_down/moving_mean:0                    (32,)
# bn_down1_down/bn_down1_down/moving_variance:0                (32,)
# bn_down1_main_1/bn_down1_main_1/beta:0                       (16,)
# bn_down1_main_1/bn_down1_main_1/gamma:0                      (16,)
# bn_down1_main_1/bn_down1_main_1/moving_mean:0                (16,)
# bn_down1_main_1/bn_down1_main_1/moving_variance:0            (16,)
# bn_down2_down/bn_down2_down/beta:0                           (64,)
# bn_down2_down/bn_down2_down/gamma:0                          (64,)
# bn_down2_down/bn_down2_down/moving_mean:0                    (64,)
# bn_down2_down/bn_down2_down/moving_variance:0                (64,)
# bn_down2_main_1/bn_down2_main_1/beta:0                       (32,)
# bn_down2_main_1/bn_down2_main_1/gamma:0                      (32,)
# bn_down2_main_1/bn_down2_main_1/moving_mean:0                (32,)
# bn_down2_main_1/bn_down2_main_1/moving_variance:0            (32,)
# bn_down3_down/bn_down3_down/beta:0                           (128,)
# bn_down3_down/bn_down3_down/gamma:0                          (128,)
# bn_down3_down/bn_down3_down/moving_mean:0                    (128,)
# bn_down3_down/bn_down3_down/moving_variance:0                (128,)
# bn_down3_main_1/bn_down3_main_1/beta:0                       (64,)
# bn_down3_main_1/bn_down3_main_1/gamma:0                      (64,)
# bn_down3_main_1/bn_down3_main_1/moving_mean:0                (64,)
# bn_down3_main_1/bn_down3_main_1/moving_variance:0            (64,)
# bn_down4_down/bn_down4_down/beta:0                           (256,)
# bn_down4_down/bn_down4_down/gamma:0                          (256,)
# bn_down4_down/bn_down4_down/moving_mean:0                    (256,)
# bn_down4_down/bn_down4_down/moving_variance:0                (256,)
# bn_down4_main_1/bn_down4_main_1/beta:0                       (128,)
# conv_down2_main_1/conv_down2_main_1/bias:0                   (32,)
# conv_down2_main_1/conv_down2_main_1/kernel:0                 (10, 10, 32, 32)
# conv_down3_down/conv_down3_down/bias:0                       (128,)
# conv_down3_down/conv_down3_down/kernel:0                     (2, 2, 64, 128)
# conv_down3_main_1/conv_down3_main_1/bias:0                   (64,)
# conv_down3_main_1/conv_down3_main_1/kernel:0                 (10, 10, 64, 64)
# conv_down4_down/conv_down4_down/bias:0                       (256,)
# conv_down4_down/conv_down4_down/kernel:0                     (2, 2, 128, 256)
# conv_down4_main_1/conv_down4_main_1/bias:0                   (128,)
# conv_down4_main_1/conv_down4_main_1/kernel:0                 (10, 10, 128, 128)
# conv_out/conv_out/bias:0                                     (3,)
# conv_out/conv_out/kernel:0                                   (1, 1, 32, 3)
# conv_up1_main_1/conv_up1_main_1/bias:0                       (256,)
# conv_up1_main_1/conv_up1_main_1/kernel:0                     (10, 10, 256, 256)
# conv_up1_up/conv_up1_up/bias:0                               (256,)
# conv_up1_up/conv_up1_up/kernel:0                             (2, 2, 256, 256)
# conv_up2_main_1/conv_up2_main_1/bias:0                       (256,)
# conv_up2_main_1/conv_up2_main_1/kernel:0                     (10, 10, 384, 256)
# conv_up2_up/conv_up2_up/bias:0                               (256,)
# conv_up2_up/conv_up2_up/kernel:0                             (2, 2, 256, 256)
# conv_up3_main_1/conv_up3_main_1/bias:0                       (128,)
# conv_up3_main_1/conv_up3_main_1/kernel:0                     (10, 10, 320, 128)
# conv_up3_up/conv_up3_up/bias:0                               (128,)
# conv_up3_up/conv_up3_up/kernel:0                             (2, 2, 128, 128)
# conv_up4_main_1/conv_up4_main_1/bias:0                       (64,)
# conv_up4_main_1/conv_up4_main_1/kernel:0                     (10, 10, 160, 64)
# conv_up4_up/conv_up4_up/bias:0                               (64,)
# conv_up4_up/conv_up4_up/kernel:0                             (2, 2, 64, 64)
# conv_up5_main_1/conv_up5_main_1/bias:0                       (32,)
# conv_up5_main_1/conv_up5_main_1/kernel:0                     (10, 10, 80, 32)

# %%
model = DeepVOG()

# %%
d = OrderedDict()
for k in range(model.layers_down):
    k1 = k+1
    d.update(tf_conv2d_to_torch(f[f'conv_down{k1}_main_1/conv_down{k1}_main_1'], f'down_{k1}.conv_main.'))
    d.update(tf_bn_to_torch(f[f'bn_down{k1}_main_1/bn_down{k1}_main_1'], f'down_{k1}.bn_main.'))
    d.update(tf_conv2d_to_torch(f[f'conv_down{k1}_down/conv_down{k1}_down'], f'down_{k1}.conv_down.'))
    d.update(tf_bn_to_torch(f[f'bn_down{k1}_down/bn_down{k1}_down'], f'down_{k1}.bn_down.'))
for k in range(model.layers_up):
    k1 = k+1
    d.update(tf_conv2d_to_torch(f[f'conv_up{k1}_main_1/conv_up{k1}_main_1'], f'up_{k1}.conv_main.'))
    d.update(tf_bn_to_torch(f[f'bn_up{k1}_main_1/bn_up{k1}_main_1'], f'up_{k1}.bn_main.'))
    if k1<5:
        d.update(tf_conv2d_to_torch(f[f'conv_up{k1}_up/conv_up{k1}_up'], f'up_{k1}.conv_up.'))
        d.update(tf_bn_to_torch(f[f'bn_up{k1}_up/bn_up{k1}_up'], f'up_{k1}.bn_up.'))
d.update(tf_conv2d_to_torch(f[f'conv_out/conv_out'], f'conv_out.'))

# %%
model.load_state_dict(d)
# Out:
# <All keys matched successfully>

# %%
torch.save(model.state_dict(), 'DeepVOG_weights.pt')

# %%
for key in d.keys():
    print(f'{key:40} {str(tuple(d[key].shape)):15}')
# Out:
# down_1.conv_main.weight                  (16, 3, 10, 10)
# down_1.conv_main.bias                    (16,)
# down_1.bn_main.weight                    (16,)
# down_1.bn_main.bias                      (16,)
# down_1.bn_main.running_mean              (16,)
# down_1.bn_main.running_var               (16,)
# down_1.bn_main.num_batches_tracked       ()
# down_1.conv_down.weight                  (32, 16, 2, 2)
# down_1.conv_down.bias                    (32,)
# down_1.bn_down.weight                    (32,)
# down_1.bn_down.bias                      (32,)
# down_1.bn_down.running_mean              (32,)
# down_1.bn_down.running_var               (32,)
# down_1.bn_down.num_batches_tracked       ()
# down_2.conv_main.weight                  (32, 32, 10, 10)
# down_2.conv_main.bias                    (32,)
# down_2.bn_main.weight                    (32,)
# down_2.bn_main.bias                      (32,)
# down_2.bn_main.running_mean              (32,)
# down_2.bn_main.running_var               (32,)
# down_2.bn_main.num_batches_tracked       ()
# down_2.conv_down.weight                  (64, 32, 2, 2)
# down_2.conv_down.bias                    (64,)
# down_2.bn_down.weight                    (64,)
# down_2.bn_down.bias                      (64,)
# down_2.bn_down.running_mean              (64,)
# down_2.bn_down.running_var               (64,)
# down_2.bn_down.num_batches_tracked       ()
# down_3.conv_main.weight                  (64, 64, 10, 10)
# down_3.conv_main.bias                    (64,)
# down_3.bn_main.weight                    (64,)
# down_3.bn_main.bias                      (64,)
# down_3.bn_main.running_mean              (64,)
# down_3.bn_main.running_var               (64,)
# down_3.bn_main.num_batches_tracked       ()
# down_3.conv_down.weight                  (128, 64, 2, 2)
# down_3.conv_down.bias                    (128,)
# down_3.bn_down.weight                    (128,)
# down_3.bn_down.bias                      (128,)
# down_3.bn_down.running_mean              (128,)
# down_3.bn_down.running_var               (128,)
# down_3.bn_down.num_batches_tracked       ()
# down_4.conv_main.weight                  (128, 128, 10, 10)
# down_4.conv_main.bias                    (128,)
# down_4.bn_main.weight                    (128,)
# down_4.bn_main.bias                      (128,)
# down_4.bn_main.running_mean              (128,)
# down_4.bn_main.running_var               (128,)
# down_4.bn_main.num_batches_tracked       ()
# down_4.conv_down.weight                  (256, 128, 2, 2)
# down_4.conv_down.bias                    (256,)
# down_4.bn_down.weight                    (256,)
# down_4.bn_down.bias                      (256,)
# down_4.bn_down.running_mean              (256,)
# down_4.bn_down.running_var               (256,)
# down_4.bn_down.num_batches_tracked       ()
# up_1.conv_main.weight                    (256, 256, 10, 10)
# up_1.conv_main.bias                      (256,)
# up_1.bn_main.weight                      (256,)
# up_1.bn_main.bias                        (256,)
# up_1.bn_main.running_mean                (256,)
# up_1.bn_main.running_var                 (256,)
# up_1.bn_main.num_batches_tracked         ()
# up_1.conv_up.weight                      (256, 256, 2, 2)
# up_1.conv_up.bias                        (256,)
# up_1.bn_up.weight                        (256,)
# up_1.bn_up.bias                          (256,)
# up_1.bn_up.running_mean                  (256,)
# up_1.bn_up.running_var                   (256,)
# up_1.bn_up.num_batches_tracked           ()
# up_2.conv_main.weight                    (256, 384, 10, 10)
# up_2.conv_main.bias                      (256,)
# up_2.bn_main.weight                      (256,)
# up_2.bn_main.bias                        (256,)
# up_2.bn_main.running_mean                (256,)
# up_2.bn_main.running_var                 (256,)
# up_2.bn_main.num_batches_tracked         ()
# up_2.conv_up.weight                      (256, 256, 2, 2)
# up_2.conv_up.bias                        (256,)
# up_2.bn_up.weight                        (256,)
# up_2.bn_up.bias                          (256,)
# up_2.bn_up.running_mean                  (256,)
# up_2.bn_up.running_var                   (256,)
# up_2.bn_up.num_batches_tracked           ()
# up_3.conv_main.weight                    (128, 320, 10, 10)
# up_3.conv_main.bias                      (128,)
# up_3.bn_main.weight                      (128,)
# up_3.bn_main.bias                        (128,)
# up_3.bn_main.running_mean                (128,)
# up_3.bn_main.running_var                 (128,)
# up_3.bn_main.num_batches_tracked         ()
# up_3.conv_up.weight                      (128, 128, 2, 2)
# up_3.conv_up.bias                        (128,)
# up_3.bn_up.weight                        (128,)
# up_3.bn_up.bias                          (128,)
# up_3.bn_up.running_mean                  (128,)
# up_3.bn_up.running_var                   (128,)
# up_3.bn_up.num_batches_tracked           ()
# up_4.conv_main.weight                    (64, 160, 10, 10)
# up_4.conv_main.bias                      (64,)
# up_4.bn_main.weight                      (64,)
# up_4.bn_main.bias                        (64,)
# up_4.bn_main.running_mean                (64,)
# up_4.bn_main.running_var                 (64,)
# up_4.bn_main.num_batches_tracked         ()
# up_4.conv_up.weight                      (64, 64, 2, 2)
# up_4.conv_up.bias                        (64,)
# up_4.bn_up.weight                        (64,)
# up_4.bn_up.bias                          (64,)
# up_4.bn_up.running_mean                  (64,)
# up_4.bn_up.running_var                   (64,)
# up_4.bn_up.num_batches_tracked           ()
# up_5.conv_main.weight                    (32, 80, 10, 10)
# up_5.conv_main.bias                      (32,)
# up_5.bn_main.weight                      (32,)
# up_5.bn_main.bias                        (32,)
# up_5.bn_main.running_mean                (32,)
# up_5.bn_main.running_var                 (32,)
# up_5.bn_main.num_batches_tracked         ()
# conv_out.weight                          (3, 32, 1, 1)
# conv_out.bias                            (3,)
